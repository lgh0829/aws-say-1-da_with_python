# %%
pip install chromedriver-autoinstaller

# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in /Users/jungin/anaconda3/lib/python3.10/site-packages (4.11.2)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/jungin/anaconda3/lib/python3.10/site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Users/jungin/anaconda3/lib/python3.10/site-packages (from selenium) (1.26.14)
# Requirement already satisfied: trio~=0.17 in /Users/jungin/anaconda3/lib/python3.10/site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/jungin/anaconda3/lib/python3.10/site-packages (from selenium) (0.10.3)
# Requirement already satisfied: idna in /Users/jungin/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /Users/jungin/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.1.3)
# Requirement already satisfied: outcome in /Users/jungin/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in /Users/jungin/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in /Users/jungin/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=20.1.0 in /Users/jungin/anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: wsproto>=0.14 in /Users/jungin/anaconda3/lib/python3.10/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/jungin/anaconda3/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/jungin/anaconda3/lib/python3.10/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import selenium
print( selenium.#TODO)  # 버전 확인
# Out:
# 3.141.0

# %%
from selenium import webdriver
import chromedriver_autoinstaller

chromedriver_autoinstaller.#TODO()  # Check if the current version of chromedriver exists
                                      # and if it doesn't exist, download it automatically,
                                      # then add chromedriver to path

driver = #TODO
driver.#TODO("http://www.python.org")
