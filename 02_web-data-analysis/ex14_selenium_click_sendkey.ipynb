# %%
from selenium import webdriver
import chromedriver_autoinstaller

chromedriver_autoinstaller.install()  # Check if the current version of chromedriver exists
                                      # and if it doesn't exist, download it automatically,
                                      # then add chromedriver to path

driver = #TODO
driver.#TODO("https://www.musinsa.com/")


from selenium.webdriver.common.by #TODO

keyword_element = driver.#TODO(#TODO, 'commonLayoutSearchForm')
keyword_element.#TODO
keyword_element.#TODO

# %%
button = driver.#TODO, 'sc-1ppcy5v-5')
button.#TODO

# %%
# 위와 동일 한 버튼을 클릭
button = driver.#TODO '/html/body/div[2]/div/header/div[2]/div/form/button')
button.#TODO
