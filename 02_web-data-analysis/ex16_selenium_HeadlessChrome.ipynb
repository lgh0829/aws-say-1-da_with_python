# %%
#Headless Chrome을 사용하면 화면을 띄우지 않고도 자동화 작업을 수행할 수 있어서 서버 환경에서도 유용하게 사용됩니다.

from selenium import webdriver
from selenium.webdriver.chrome.options #TODO

# Headless Chrome 설정
chrome_options =#TODO
chrome_options#TODOt("--headless")  # 헤드리스 모드 활성화

# ChromeDriver 실행
driver = webdriver#TODOt

# 웹 페이지 로드
driver.#TODOt("https://www.naver.com")

# 페이지 제목 출력
print("페이지 제목:", #TODOt)

# 드라이버 종료
driver.#TODOt
# Out:
# 페이지 제목: NAVER
